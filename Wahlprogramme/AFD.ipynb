# %%
! pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.3-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 53.8 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.25.3

# %%
import pymupdf as fitz

def extract_text_with_formatting(pdf_path, skip_pages=10):
    doc = fitz.open(pdf_path)
    text_data = []

    def int_to_rgb(color_int, colorspace):
        """Wandle den Farb-Integer in RGB-Tupel um, abhängig vom Farbraum."""
        if colorspace == 0:  # DeviceGray (Graustufen)
            gray = color_int & 255
            return (gray, gray, gray)
        elif colorspace == 1:  # DeviceRGB (Standard-RGB)
            return ((color_int >> 16) & 255, (color_int >> 8) & 255, color_int & 255)
        elif colorspace == 2:  # DeviceCMYK (Annäherung, da PyMuPDF keine direkte Umwandlung macht)
            c = (color_int >> 24) & 255
            m = (color_int >> 16) & 255
            y = (color_int >> 8) & 255
            k = color_int & 255
            # Annäherung: Konvertiere CMYK grob zu RGB
            r = 255 * (1 - c / 255) * (1 - k / 255)
            g = 255 * (1 - m / 255) * (1 - k / 255)
            b = 255 * (1 - y / 255) * (1 - k / 255)
            return (int(r), int(g), int(b))
        else:
            return (0, 0, 0)  # Standard: Schwarz

    # Schleife über Seiten
    for page_num in range(skip_pages, 176):
        page = doc.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]  # Extrahiert Textblöcke

        # Schleife über Textblöcke
        for block in blocks:
            if block["type"] == 0:  # Textblock
                for line in block["lines"]:
                    for span in line["spans"]:
                        # Extrahiere Farbraum (Standard: RGB = 1)
                        colorspace = span.get("colorspace", 1)
                        color_rgb = int_to_rgb(span["color"], colorspace)

                        # Speichere Text + Schriftgröße + Fett + RGB-Farbe
                        text_data.append({
                            "text": span["text"],
                            "size": span["size"],  # Schriftgröße
                            "bold": span["flags"] & 2 != 0,  # Prüft, ob der Text fett ist
                            "color_rgb": color_rgb,  # RGB-Tupel
                            "colorspace": colorspace  # Farbraum zur Kontrolle
                        })

    doc.close()
    return text_data

# PDF-Dateipfad
pdf_path = "/content/Wahlprogramm_AFD.pdf"

# Text mit Formatierungsinformationen extrahieren
text_data = extract_text_with_formatting(pdf_path)

# Beispiel: Zeige die ersten 130 Textabschnitte mit Formatierung
for item in text_data[:130]:
    print(f"Text: {item['text']}, Size: {item['size']}, Bold: {item['bold']}, Color: {item['color_rgb']}, Colorspace: {item['colorspace']}")
# Out:
# Text: 10, Size: 10.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: SOZIALE MARKTWIRTSCHAFT, Size: 14.0, Bold: True, Color: (0, 0, 0), Colorspace: 1
# Text: Wir stehen fest zu den Prinzipien der Sozialen Marktwirtschaft, die , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: seit Jahrzehnten Wohlstand und sozialen Frieden in unserem Land , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: sichern. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wir wollen in einer Zeit globaler Herausforderungen die Grundwerte , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: unserer Wirtschaftsordnung bewahren und so weiterentwickeln, , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: dass wir eine freiheitliche und erfolgreiche Gesellschaft gewährleis-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: ten, in der die Bürger ihr Leben eigenverantwortlich und selbstbe-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: stimmt führen können., Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wir setzen uns für eine wettbewerbsfähige Wirtschaft ein, die Innova-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: tion und Unternehmertum fördert, Wohlstand für alle schafft und ins-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: besondere dem Mittelstand neue Entfaltungsmöglichkeiten eröffnet. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wir treten dafür ein, dass Arbeitnehmer immer deutlich besserge-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: stellt sind als Empfänger von Sozialleistungen. Ihre Arbeit soll eine , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: auskömmliche und sichere Rente gewährleisten. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wir tragen Sorge dafür, dass wirklich Bedürftige in den Grundsi-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: cherungssystemen aufgefangen werden. Ein selbstgewähltes Leben , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: auf Kosten der Allgemeinheit wird nicht gefördert. Mit unseren , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Maßnahmen bringen wir wieder Optimismus und Zuversicht in die , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Gesellschaft. Viele Regelungen der EU schwächen Wirtschaft und , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wettbewerb, statt sie zu stärken. Beispiele dafür sind der „Green , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Deal“ und der Einfluss auf Energiefragen., Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Freies Unternehmertum und Wirtschaftsstandort stärken, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wir streben eine funktionierende Wirtschaft an, die aus eigener , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Kraft und Profitabilität in Forschung und Entwicklung investiert, um , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: dem internationalen Markt innovative und wettbewerbsfähige An-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: SOZIALE MARKTWIRTSCHAFT UND GESUNDHEIT, Size: 10.0, Bold: False, Color: (0, 162, 227), Colorspace: 1
# Text: 11, Size: 10.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: gebote zu machen. Deutsche Unternehmen sollen an der Weltspitze , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: der Exportunternehmen stehen und „Made in Germany“ wieder zu , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: einem Markenzeichen für Exzellenz und Einzigartigkeit machen. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Dafür streben wir eine auf Leistung und Talentförderung ausgelegte , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Schul- und Berufsausbildung an. Unsere Universitäten sollen in die , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Lage versetzt werden, erstklassige Talente aus Deutschland und aller , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Welt anzuziehen und unser Land in den Top-Branchen zu einem , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: internationalen Innovationsführer zu machen. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Dazu zählen wir neben den Traditionsbranchen wie Automobilbau, , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Maschinenbau, Chemie auch moderne Hochtechnologien wie Du-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: al-Fluid-Nukleartechnik, Weltraumtechnologie, Nano-Technologie , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: und Künstliche Intelligenz. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Deutschland ist als Wirtschaftsstandort unattraktiv geworden, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Deutschland ragte in früheren Jahrzehnten international heraus , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: durch wirtschaftliche und wissenschaftliche Exzellenz. Die gegen-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: wärtige Situation ist hingegen von einem wirtschaftlichen und , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: wissenschaftlichen Niedergang geprägt. Technologievorgaben, Auf-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: lagen und Verbote setzen den marktwirtschaftlichen Wettbewerb in , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Teilen außer Kraft; suboptimale technische Lösungen und Produkte , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: sind die Folge. Viele davon sind ohne staatliche Subventionen nicht , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: marktfähig, zum Beispiel alternative Energien und Elektroautos. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Viele Auflagen sind zudem mit den Ressourcen unseres Landes , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: nicht zu vereinbaren. Dies gilt für den eingeschränkten Zugang zu , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Rohstoffen wie seltene Erden für alternative Energien und Antriebe, , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: zu preiswerter fossiler oder nuklearer Energie genauso wie für gut , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: ausgebildete in- und ausländische Fachkräfte. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Unsere Schulbildung erfolgt nicht mehr nach dem Leistungsprin-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: zip. Auch mangelt es an Basiswissen in Mathematik und Deutsch , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: SOZIALE MARKTWIRTSCHAFT UND GESUNDHEIT, Size: 10.0, Bold: False, Color: (0, 162, 227), Colorspace: 1
# Text: 12, Size: 10.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: am Ende der Grundschule. Dies setzt sich im weiteren Schulverlauf , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: fort, wodurch zahlreiche Schulabgänger nicht mehr ausbildungs-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: fähig sind. Während fast alle anderen Länder ihre Schulleistungen , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: verbessern konnten, ist das einst führende Deutschland im weltwei-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: ten Vergleich auf ein mittleres Niveau zurückgefallen. Nachfolgende , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Generationen sind so nicht mehr international wettbewerbsfähig. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Für gut ausgebildete Fachkräfte aus dem In- und Ausland ist , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Deutschland nicht mehr attraktiv: Zu abschreckend sind hohe Steu-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: ern und Abgaben, mangelnde Sicherheit im öffentlichen Raum, un-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: zureichende Schulbildung in öffentlichen Schulen, knapper, teurer , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wohnraum sowie geringe Chancen auf Eigentumsbildung und eine , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: auskömmliche Alterssicherung. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Deutsche Unternehmenssteuern sind im internationalen Ver-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: gleich zu hoch und hindern unsere Unternehmen daran, dringend , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: benötigte Zukunftsinvestitionen vorzunehmen. Das kaum noch , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: zu überblickende Ausmaß an Regulierung und Verboten senkt die , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Attraktivität unseres Wirtschaftsstandorts für in- und ausländische , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Investoren. Eine fortschrittliche wirtschaftliche Entwicklung wird , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: dadurch zusätzlich erschwert. So fließt seit einigen Jahren viel mehr , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Investitionskapital aus Deutschland heraus als hereinfließt. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Vor allem für Mittelstand und Landwirtschaft sind die strangulieren-, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: den Vorgaben der Politik nicht mehr zu bewältigen. Viele Betriebe , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: geben auf oder suchen neue Chancen im Ausland. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Die immense Steuer- und Abgabenlast führt in Teilbereichen der , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wirtschaft vermehrt zu Schwarzarbeit, schwarzen Kassen und , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Lohndumping in verschachtelten Subunternehmer-Pyramiden. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Dadurch entsteht an Staat und Steuer vorbei eine Parallelwirtschaft , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: in einer Größenordnung von Hunderten Milliarden. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: SOZIALE MARKTWIRTSCHAFT UND GESUNDHEIT, Size: 10.0, Bold: False, Color: (0, 162, 227), Colorspace: 1
# Text: 13, Size: 10.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Vorrang für den Wettbewerb – für einen attraktiven , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wirtschaftsstandort, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Staatliche Eingriffe in den Markt werden wir auf ein Minimum , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: reduzieren. Wir sorgen stattdessen für Rahmenbedingungen, die , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Deutschland wieder attraktiv machen und unsere internationale , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Wettbewerbsfähigkeit wieder herstellen. , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Damit Unternehmer an die Zukunft des Standorts Deutschland , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: glauben können, werden wir den Zugang zu sicherer und  , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: bezahlbarer Energie wiederherstellen durch: , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Verlängerung der Laufzeiten der Kohlekraftwerke, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Wiedereinstieg in die Nutzung der Kernenergie, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Reparatur und Wiederinbetriebnahme der Nord-Stream-Pipelines, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Aufhebung des Verbots von Gas- und Ölheizungen, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Abschaffung der CO₂-Abgabe, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Reduzierung der Energiesteuer und Senkung der Stromsteuer , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: auf das Minimum, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Verhinderung immer höherer Netzentgelte durch Windenergie- , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Ausbaustopp, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Strangulierende Bürokratie und wettbewerbsverzerrende , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: Vorschriften reduzieren wir durch:, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Abschaffung von Lieferkettensorgfaltsgesetz und EU-Liefer- , Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: kettenrichtlinie, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1
# Text: 	, Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: , Size: 9.0, Bold: False, Color: (0, 104, 180), Colorspace: 1
# Text: Abschaffung des Verpackungsgesetzes, Size: 9.0, Bold: False, Color: (0, 0, 0), Colorspace: 1

# %%
## Output anschauen: Normale Schrift ist in Schriftgröße 9, Überschriften sind größer und nur Großbuchstaben
## Seitenzahlen stehen in einzelnen Zeilen in Größe 10
## viele leere Zeilen


import pandas as pd

def split_sections(text_data, min_size=9, bold_threshold=True):
    sections = []
    current_section = []

    for item in text_data:
        text = item["text"]

        if item["size"] > min_size and text.isupper() and item['bold'] == bold_threshold: # Überschriften überspringen + Abschnitt definieren
            if current_section:
                sections.append(" ".join(current_section).strip())
            current_section = []  # Abschnitt zurücksetzen

        elif text.isdigit() and len(text) <= 4:  # Seitenzahlen überspringen
            continue

        elif text.isupper() and item["bold"] == False: # Kopfzeile überspringen überspringen
            continue
        else:
            current_section.append(text)

    if current_section:
        sections.append(" ".join(current_section).strip()) # Text hinzufügen

    return sections



# Abschnitte extrahieren
sections = split_sections(text_data)

# Erstelle eine Tabelle mit den Abschnitten
df = pd.DataFrame(sections, columns=["Abschnitt"])

print(df[:10])
# Out:
#                                            Abschnitt
# 0  Wir stehen fest zu den Prinzipien der Sozialen...
# 1  Wir streben eine Rentenversicherung an, mit de...
# 2  Einen Anspruch auf Leistungen aus der Arbeitsl...
# 3  In Deutschland sind die Beiträge für die Krank...
# 4  Wir streben einen wirtschaftlichen Zustand an,...
# 5  Da alle erwachsenen Bürgergeldempfänger grunds...
# 6  Beim bestehenden deutschen Gesundheitssystem z...
# 7  In weiten Teilen Deutschlands herrscht unter a...
# 8  Eine Infrastruktur für Deutschlands Zukunft Ni...
# 9  Die jahrzehntelange Fokussierung auf die ideol...

# %%
import pandas as pd

def split_sections(text_data, min_size=9, bold_threshold=True):
    sections = []
    current_section = []

    # Hilfsfunktion zur Erkennung von Überschriften, die zwischen zwei leeren Zeilen stehen
    def is_spacing_heading(index):
        # Prüfen, ob vorherige und nächste Zeile leer sind (falls vorhanden)
        prev_empty = index > 0 and text_data[index - 1]["text"].strip() == ""
        next_empty = index + 1 < len(text_data) and text_data[index + 1]["text"].strip() == ""
        return prev_empty and next_empty

    for i, item in enumerate(text_data):
        text = item["text"].strip()

        # Seitenzahlen überspringen
        if text.isdigit() and len(text) <= 4:
            continue

        # Leere Zeile überspringen
        if text == "":
            continue

        # Hauptüberschrift: groß, fett, Größe > min_size
        if item["size"] > min_size and text.isupper() and item['bold'] == bold_threshold:
            if current_section:
                sections.append(" ".join(current_section).strip())
            current_section = []
            continue

        # Zwischenüberschrift: groß, nicht fett
        elif text.isupper() and not item["bold"]:
            continue

        # Neue Logik: Überschrift zwischen zwei leeren Zeilen
        elif is_spacing_heading(i):
            if current_section:
                sections.append(" ".join(current_section).strip())
            current_section = []
            continue

        # Standard-Text zum aktuellen Abschnitt hinzufügen
        else:
            current_section.append(text)

    # Letzten Abschnitt hinzufügen
    if current_section:
        sections.append(" ".join(current_section).strip())

    return sections


# Test der Funktion
sections = split_sections(text_data)

# Erstelle DataFrame
df = pd.DataFrame(sections, columns=["Abschnitt"])
print(df)
# Out:
#                                             Abschnitt
# 0   Wir stehen fest zu den Prinzipien der Sozialen...
# 1   Wir streben eine Rentenversicherung an, mit de...
# 2   Einen Anspruch auf Leistungen aus der Arbeitsl...
# 3   In Deutschland sind die Beiträge für die Krank...
# 4   Wir streben einen wirtschaftlichen Zustand an,...
# 5   Da alle erwachsenen Bürgergeldempfänger grunds...
# 6   Beim bestehenden deutschen Gesundheitssystem z...
# 7   In weiten Teilen Deutschlands herrscht unter a...
# 8   Eine Infrastruktur für Deutschlands Zukunft Ni...
# 9   Die jahrzehntelange Fokussierung auf die ideol...
# 10  Verkehrspolitik – ideologiefrei und bedarfsger...
# 11  Die Digitalisierung ist aus der modernen Gesel...
# 12  Der Staat erhebt Steuern auch mit dem Ziel, du...
# 13                                                  -
# 14  Deutschland hat kein Einnahmen-, sondern ein A...
# 15  Das deutsche Steuerrecht ist mit über 30.000 V...
# 16  Zurück zu Recht, Wohlstand und sozialem Friede...
# 17  Reine Luft und sauberes Wasser, gesunde und ve...
# 18  Außenpolitik muss Realpolitik in deutschem Int...
# 19  Die deutschen Streitkräfte sind nicht verteidi...
# 20  In den vergangenen Jahrzehnten wurden die poli...
# 21  Deutsches Recht schließt die Einreise zum Zwec...
# 22  Deutschland trägt aufgrund seiner Regierungspo...
# 23  Das deutsche Rückführungsversagen ist nicht lä...
# 24  Leitgedanken bei jeder Form von Zuwanderung mü...
# 25  Wir begrüßen die Zuwanderung qualifizierter Fa...
# 26  Eine der Grundvoraussetzungen für die innere S...
# 27  Ausländerkriminalität: Der weitere Anstieg des...
# 28  Die AfD bekennt sich zum antitotalitären Gründ...
# 29  In Zeiten fast ungehinderter Migration sowie g...
# 30  Bund und Länder haben mit ihrer Europa-, Migra...
# 31  Staaten und nichtstaatliche Organisationen wir...
# 32  Das parteienstaatliche parlamentarische Regier...
# 33  Die AfD steht seit ihrer Gründung zu der Idee ...
# 34  Die Familie, bestehend aus Vater, Mutter und K...
# 35  Das Menschenbild der AfD sieht jedes Individuu...
# 36  Die AfD befürwortet ein nach Begabungen differ...
# 37  Die duale Ausbildung in Unternehmen und Berufs...
# 38  Die Integration von Migranten ist eine Herausf...
# 39  Bologna ist gescheitert: Diplom und Magister w...
# 40  Die AfD vertraut auf die menschliche Innovatio...
# 41  Unsere Identität bestimmt die grundlegenden We...
# 42  GRUNDFUNK statt GEZ-Zwangsabgabe Mit rund 9 Mi...

# %%
# Speichern der Tabelle als CSV-Datei
df.to_csv("/content/afd.csv", index=False, encoding="utf-8")
